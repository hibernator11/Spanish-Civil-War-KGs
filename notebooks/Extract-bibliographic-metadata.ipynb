# %% [markdown]
# ## Retrieving bibliographic records related to the Spanish Civil War from the Biblioteca Virtual Miguel de Cervantes LOD repository
#
# This example employs a SPARQL query to retrieve up to 100 works related to the subject "España -- Historia -- 1936-1939 (Guerra civil)" from the Biblioteca Virtual Miguel de Cervantes LOD repository available at https://data.cervantesvirtual.com/sparql.
#
# This example shows how to use <a href="https://www.w3.org/TR/sparql11-query/">SPARQL</a> as a query language in Linked Open Data repositories.

# %% [markdown]
# ### First of all, we init the SPARQLWrapper service with the SPARQL endpoint

# %%
from SPARQLWrapper import SPARQLWrapper

sparql = SPARQLWrapper("http://data.cervantesvirtual.com/openrdf-sesame/repositories/data")

# %% [markdown]
# ### Then we define our CONSTRUCT query to extract the metadata

# %%
sparql.setQuery("""
PREFIX rdac: <http://rdaregistry.info/Elements/c/>
PREFIX rdaw: <http://rdaregistry.info/Elements/w/>

CONSTRUCT {
    # ?s rdf:type rdac:Work .
    # ?s rdaw:author ?author .
    # ?s dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" .
    # ?s rdaw:titleOfTheWork ?title .
    # ?s rdaw:formOfWork ?form
}WHERE {
    # ?s rdf:type rdac:Work .
    # ?s rdaw:author ?author .
    # ?s dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" .
    # ?s rdaw:titleOfTheWork ?title .
    OPTIONAL {?s rdaw:formOfWork ?form}
} 
LIMIT 100
"""
)

# %% [markdown]
# ### Finally, we serialise the result

# %%
results = sparql.queryAndConvert()
print(results.serialize())
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix rdaw: <http://rdaregistry.info/Elements/w/> .
#
# <https://data.cervantesvirtual.com/work/1048971> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/108269> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El carlismo ante la reorganización de las derechas. De la Segunda Guerra Carlista a la Guerra Civil" .
#
# <https://data.cervantesvirtual.com/work/1049318> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/9728> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Una encuesta política en la España de la preguerra" .
#
# <https://data.cervantesvirtual.com/work/1055461> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/77119> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El caso de Lorca" .
#
# <https://data.cervantesvirtual.com/work/1055714> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/108138> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Los personajes de Chirbes y la guerra y posguerra españolas" .
#
# <https://data.cervantesvirtual.com/work/1066515> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/11550> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026191> ;
#     rdaw:titleOfTheWork "Al año de guerra. Por la libertad, por la República, por España" .
#
# <https://data.cervantesvirtual.com/work/1129901> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/9616> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La guerra civil de 1936-1939 en la novela española del último decenio del siglo xx " .
#
# <https://data.cervantesvirtual.com/work/1133547> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/113525> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La tragedia del espíritu español (octubre 1936)" .
#
# <https://data.cervantesvirtual.com/work/1134744> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/113649> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """La cara oculta de la contrainsurgencia franquista a través de un mando de la Guardia Civil: la experiencia de Eulogio Limia Pérez
#
# """ .
#
# <https://data.cervantesvirtual.com/work/1137499> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/9616> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Historia y ficción, historia y discurso: doble dualismo. Análisis narratológico de tres novelas de la Guerra Civil española " .
#
# <https://data.cervantesvirtual.com/work/1145248> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/4432> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026191> ;
#     rdaw:titleOfTheWork "En el frente de Extremadura" .
#
# <https://data.cervantesvirtual.com/work/1145631> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/113026> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Significado del teatro alegórico y social: del drama sacro a las tragedias de patrono. Las puestas en escena" .
#
# <https://data.cervantesvirtual.com/work/1145646> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/114503> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026039> ;
#     rdaw:titleOfTheWork "Las voces femeninas en \"Un largo silencio\" de Ángeles Caso desde una perspectiva bajtiniana" .
#
# <https://data.cervantesvirtual.com/work/1199823> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/11174> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "
a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/73691> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Carlota O'Neill: sobrevivir para recordar" .
#
# <https://data.cervantesvirtual.com/work/849579> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83360> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Max Aub. El exilio y el abandono de la realidad" .
#
# <https://data.cervantesvirtual.com/work/849585> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83361> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """El archivo de la Spanish Refugee Aid. Otras voces y otras vidas del exilio
# """ .
#
# <https://data.cervantesvirtual.com/work/849589> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83357> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La República en el recuerdo: de la realidad a la esperanza" .
#
# <https://data.cervantesvirtual.com/work/849594> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/13591> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """La República en el exilio: un Gobierno sin pueblo y sin tierra
# """ .
#
# <https://data.cervantesvirtual.com/work/849597> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83363> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Juristas en el exilio " .
#
# <https://data.cervantesvirtual.com/work/849600> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83362> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La República, hoy y mañana" .
#
# <https://data.cervantesvirtual.com/work/849606> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83364> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Exilios. Escritores españoles en Estados Unidos " .
#
# <https://data.cervantesvirtual.com/work/849612> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/77929> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El exilio en la \"Luna\"" .
#
# <https://data.cervantesvirtual.com/work/849615> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/13591> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El cine" .
#
# <https://data.cervantesvirtual.com/work/849623> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83365> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La mujer en la política y en la cultura" .
#
# <https://data.cervantesvirtual.com/work/849624> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83364> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """La violencia del olvido. Mujeres norteamericanas en la Guerra Civil
# Española """ .
#
# <https://data.cervantesvirtual.com/work/849635> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83367> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Juan de Mairena en \"La Vanguardia\". El final (1938) " .
#
# <https://data.cervantesvirtual.com/work/849636> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83368> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El universo femenino de la República" .
#
# <https://data.cervantesvirtual.com/work/849639> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83369> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """¿Los intelectuales en el destierro? La ideología del exilio
# """ .
#
# <https://data.cervantesvirtual.com/work/849642> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/13607> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El exilio: Francia " .
#
# <https://data.cervantesvirtual.com/work/849645> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83370> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "El derecho a la República" .
#
# <https://data.cervantesvirtual.com/work/849649> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83373> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La República se (re)publica " .
#
# <https://data.cervantesvirtual.com/work/849659> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83374> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """Antonio Espina. Vanguardia literaria y compromiso político
# """ .
#
# <https://data.cervantesvirtual.com/work/849662> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/77108> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """El Madrid épico de la guerra cantado por los poetas
# """ .
#
# <https://data.cervantesvirtual.com/work/849665> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/76689> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Literatura republicana, literatura proletaria, literatura revolucionaria" .
#
# <https://data.cervantesvirtual.com/work/849666> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/11659> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Los intelectuales árabes en la Guerra Civil de España " .
#
# <https://data.cervantesvirtual.com/work/849674> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83377> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Guerra, poesía y \"Niebla\". Análisis de un poema " .
#
# <https://data.cervantesvirtual.com/work/849678> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83375> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La República y la ciencia" .
#
# <https://data.cervantesvirtual.com/work/849706> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83385> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """La amargura de la derrota (el general Rojo en Buenos Aires)
# """ .
#
# <https://data.cervantesvirtual.com/work/849713> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83386> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Las mujeres en la República" .
#
# <https://data.cervantesvirtual.com/work/849758> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83370> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Hacia una República federal" .
#
# <https://data.cervantesvirtual.com/work/849812> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83388> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Ortega y Azaña, dos visiones de la República " .
#
# <https://data.cervantesvirtual.com/work/849815> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83377> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La poesía política de Alberti" .
#
# <https://data.cervantesvirtual.com/work/849821> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/13592> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """Los escritores y la República
# """ .
#
# <https://data.cervantesvirtual.com/work/849833> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83390> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Gratitud cubana a la República española " .
#
# <https://data.cervantesvirtual.com/work/849842> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83391> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Max Aub en el exilio: el compromiso de la vanguardia " .
#
# <https://data.cervantesvirtual.com/work/849848> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83392> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "\"Viridiana\" entre dos exilios " .
#
# <https://data.cervantesvirtual.com/work/849851> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/13591>,
#         <https://data.cervantesvirtual.com/person/77929> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork """El exilio en el recuerdo: "No hay identidad, hay identificación".
# Entrevista al poeta Tomás Segovia """ .
#
# <https://data.cervantesvirtual.com/work/849878> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83395>,
#         <https://data.cervantesvirtual.com/person/83396> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Canciones del bando republicano " .
#
# <https://data.cervantesvirtual.com/work/849882> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/13591> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Entre dos derechos iguales decide la fuerza " .
#
# <https://data.cervantesvirtual.com/work/849890> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83369> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Escritores en guerra " .
#
# <https://data.cervantesvirtual.com/work/849899> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83388> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Ortodoxia y heterodoxia: consecuencias de la Guerra Civil " .
#
# <https://data.cervantesvirtual.com/work/849914> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/83398> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "España y españoles en la Hispano-Cubana de Cultura " .
#
# <https://data.cervantesvirtual.com/work/849917> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/73691> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Las mujeres en \"Hora de España\"" .
#
# <https://data.cervantesvirtual.com/work/850026> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/74720> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Francisco Ayala" .
#
# <https://data.cervantesvirtual.com/work/884284> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/86394> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Stephanie Sieburth: \"Coplas para sobrevivir. Conchita Piquer, los vencidos y la represión franquista\". Madrid: Cátedra, 2016, 302 págs. [Reseña]" .
#
# <https://data.cervantesvirtual.com/work/924324> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/9554> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026191> ;
#     rdaw:titleOfTheWork "La persona y el Estado" .
#
# <https://data.cervantesvirtual.com/work/926750> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/89496> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "\"La verdadera historia de la muerte de Francisco Franco\", de Max Aub, o la necesidad de reescribir la historia" .
#
# <https://data.cervantesvirtual.com/work/933894> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/90620> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La II República y la Guerra Civil en el debate político actual" .
#
# <https://data.cervantesvirtual.com/work/935813> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/corporatebody/73791> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026191> ;
#     rdaw:titleOfTheWork "1936 de la Revolución Española" .
#
# <https://data.cervantesvirtual.com/work/943476> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/7962> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La \"Guerra Civil\" como categoría cultural" .
#
# <https://data.cervantesvirtual.com/work/969704> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/92830> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "De Málaga a México, de la República al exilio. El legado de Juan Antonio Ortega y Medina" .
#
# <https://data.cervantesvirtual.com/work/969713> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/92833> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Juan Antonio Ortega y Medina. Retrato íntimo" .
#
# <https://data.cervantesvirtual.com/work/972241> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/93031>,
#         <https://data.cervantesvirtual.com/person/93032>,
#         <https://data.cervantesvirtual.com/person/93033> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La Guerra Civil en Castilla y León: ensayo general para la dictadura franquista" .
#
# <https://data.cervantesvirtual.com/work/972244> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/93034> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Actitudes sociales y políticas en la denominada recuperación de la memoria histórica. Galicia: el proyecto de investigación interuniversitario \"Nomes e Voces\"" .
#
# <https://data.cervantesvirtual.com/work/972277> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/93036>,
#         <https://data.cervantesvirtual.com/person/93037> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "\"El Liberal\", de Sevilla (1901-1936). Un diario independiente en la Andalucía anterior a la Guerra Civil" .
#
# <https://data.cervantesvirtual.com/work/976242> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/93304> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Luis Jiménez de Asúa y la gestación de la política de \"No Intervención\" en la Guerra Civil Española" .
#
# <https://data.cervantesvirtual.com/work/976248> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/93305> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Los refugiados de la guerra civil como sujeto colectivo en las comarcas de Castellón de la Plana" .
#
# <https://data.cervantesvirtual.com/work/980192> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/93410> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "La casta militar africanista : (1936)" .
#
# <https://data.cervantesvirtual.com/work/996999> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/95488> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "De la cultura de guerra a la cultura de la victoria: los vencedores y la construcción de la dictadura franquista (1936-1951) " .
#
# <https://data.cervantesvirtual.com/work/997005> a <http://rdaregistry.info/Elements/c/Work> ;
#     dc:subject "España -- Historia -- 1936-1939 (Guerra civil)" ;
#     rdaw:author <https://data.cervantesvirtual.com/person/95490> ;
#     rdaw:formOfWork <http://id.loc.gov/authorities/genreForms/gf2014026168> ;
#     rdaw:titleOfTheWork "Los bombardeos italianos sobre el País Valenciano durante la Guerra Civil española: un estudio fotográfico " .

# %% [markdown]
# ### We can save the results to a file

# %%
with open("output/bibliographic.ttl", "w") as text_file:
    text_file.write(results.serialize())

# %% [markdown]
# ### We can also provide metadata about the extracted dataset using ontologies and controlled vocabularies

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import FOAF, RDF, DCTERMS, VOID, DC, SKOS, OWL
import datetime

# %%
domain = 'https://example.org/'

g = Graph()
g.bind("foaf", FOAF)
g.bind("rdf", RDF)
g.bind("dcterms", DCTERMS)
g.bind("dc", DC)
g.bind("void", VOID)
g.bind("skos", SKOS)
g.bind("owl", OWL)

schema = Namespace("https://schema.org/")
g.bind("schema", schema)

viaf = Namespace("https://viaf.org/viaf/")
g.bind("viaf", viaf)

wd = Namespace("http://www.wikidata.org/entity/")
g.bind("wd", wd)

# %%
dataset = URIRef(domain + "dataset/bibliographic-metadata-bvmc")

g.add((dataset, RDF.type, schema.Dataset))
g.add((dataset, schema.url, URIRef("https://www.cervantesvirtual.com")))
g.add((dataset, schema.description, Literal("This example is based on bibliographic records related to the Spanish Civil War from the Biblioteca Virtual Miguel de Cervantes LOD repository.")))
g.add((dataset, schema.name, Literal("Bibliographic records related to the Spanish Civil War from the Biblioteca Virtual Miguel de Cervantes LOD repository")))
g.add((dataset, DC.title, Literal("Bibliographic records related to the Spanish Civil War from the Biblioteca Virtual Miguel de Cervantes LOD repository")))
g.add((dataset, schema.license, URIRef('https://creativecommons.org/publicdomain/zero/1.0/')))

now = datetime.datetime.now()
g.add((dataset, schema.dateCreated, Literal(str(now)[:10])))
# Out:
# <Graph identifier=N857dcd68bd9b4b5c80933ca7a6746d17 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Let's store the metadata generated

# %%
g.serialize(destination="output/metadata-bibliographic-bvmc.ttl")
# Out:
# <Graph identifier=N857dcd68bd9b4b5c80933ca7a6746d17 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### Finally we can analyse the metadata generated

# %%
input_file = "output/bibliographic.ttl"
g = Graph().parse(input_file)

# %% [markdown]
# Let's check the number of properties

# %%
print('##### Number of properties:')

# Query the data in g using SPARQL
q = """
    SELECT (count(distinct ?prop) as ?properties)
    WHERE {
        # ?s ?prop ?o .
    }
"""

# Apply the query to the graph and iterate through results
for r in g.query(q):
    print(r["properties"])
# Out:
# ##### Number of properties:
# 5

# %% [markdown]
# We can also check the total number of triples

# %%
print('##### Number of triples:')
    
# Query the data in g using SPARQL
q = """
    SELECT (COUNT(*) as ?triples) 
    WHERE { ?s ?p ?o } 
"""

# Apply the query to the graph and iterate through results
for r in g.query(q):
    print(r["triples"])
# Out:
# ##### Number of triples:
# 468
